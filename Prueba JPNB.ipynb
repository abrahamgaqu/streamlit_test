# %%
import matplotlib.pyplot as plt
import numpy as np 

x = [  1, 2, 3, 4, 5]
Y = [1, 4, 9, 16, 25]

plt.scatter(x, Y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of X vs Y')
plt.grid()
plt.show()
